# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [0.0, -0.4911, -0.2423, -0.2845]
y = [0.0, -0.0437, -0.0918, 0.7672]
# mean_x = np.mean(x)
# mean_y = np.mean(y)
# # Shifting the centroid of the plot to the origin
# x = x - mean_x
# y = y - mean_y - 0.15
plt.scatter(x, y, marker='o')
# Make x and y axes have the same scale
plt.axis('equal')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
print(x)
print(y)
# Out:
# [ 0.254475 -0.236625  0.012175 -0.030025]
# [-0.307925 -0.351625 -0.399725  0.459275]

# %%
pred_x = [0.0, -0.4913, -0.2425, -0.2848]
pred_y = [0.0, -0.0433, -0.0918, 0.7673]

pred_x = pred_x - mean_x
pred_y = pred_y - mean_y - 0.15

print(pred_x)
print(pred_y)
# Out:
# [ 0.254475 -0.236825  0.011975 -0.030325]
# [-0.307925 -0.351225 -0.399725  0.459375]
